# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r'C:\Jypiter\ochischennye_dannye.xlsx')
df = data.iloc[:,1:68]
df_bad = data['bad']
df.head()
df.shape
# Out:
# (1365, 67)

# %%
X_embedded = TSNE(n_components=2).fit_transform(df)
X_embedded.shape
# Out:
# (1365, 2)

# %%
plt.figure(figsize=(25,25))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=data['bad'].map({1: 'red', 0: 'blue'}))
plt.label = 'Result'

# %%
df = data.iloc[:,1:68]
plt.figure(figsize=(25,25))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=data['bad'].map({1: 'red', 0: 'blue'}))
plt.label = 'Result'

# %%
from matplotlib import pyplot as PLT

fig = PLT.figure(figsize=(25,25))

ax1 = fig.add_subplot(231)
ax1.scatter(X_embedded[:, 0], X_embedded[:, 1], 
            c=data['bad'].map({1: 'red', 0: 'blue'}));

ax2 = fig.add_subplot(232)
ax2.scatter(X_embedded[:, 0], X_embedded[:, 1], 
            c=df['x8'].map({1: 'dodgerblue', 2: 'm', 3: 'lawngreen', 4: 'red', 0: 'mediumvioletred'}));

ax3 = fig.add_subplot(233)
ax3.scatter(X_embedded[:, 0], X_embedded[:, 1], 
            c=df['x9'].map({1: 'dodgerblue', 2: 'm', 3: 'lawngreen', 4: 'red', 0: 'mediumvioletred'}));

ax4 = fig.add_subplot(234)
ax4.scatter(X_embedded[:, 0], X_embedded[:, 1], 
            c=df['x35'].map({1: 'dodgerblue', 2: 'm', 3: 'lawngreen', 4: 'red', 0: 'mediumvioletred'}));

ax5 = fig.add_subplot(235)
ax5.scatter(X_embedded[:, 0], X_embedded[:, 1], 
            c=df['x53'].map({1: 'dodgerblue', 2: 'm', 3: 'lawngreen', 4: 'red', 0: 'mediumvioletred',5: 'gold', 6: 'navy', 7: 'coral', 8: 'c', 9: 'darkorange'}));

ax1.set_title('bad');
ax2.set_title('Кол-во риск-ориентировок запросы');
ax3.set_title('Кол-во проверок');
ax4.set_title('КВО 4007 Возм. не представлено (кол-во)');
ax5.set_title('Сотня по активам');

PLT.show()
