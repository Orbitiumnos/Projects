# %%
import pandas as pd
import numpy as np

data = pd.read_excel (r'C:\Jypiter\ochischennye_dannye.xlsx')
ind = data['Кредит.организация']
df = data.iloc[:,1:68].set_index(ind)
features = list(unclr_data.columns.values)

data.head(10)
# Out:
#   Кредит.организация        x1          x2    x3    x4    x5          x6  \
# 0                КО2   5208690   157537353   205   223   114   169231559
# 1                КО3  12263861           0     0     0     0           0
# 2                КО4  12263861  8123066430   994   487   360   529987788
# 3                КО5  12263861           0     0     0     0           0
# 4                КО6   1931158   782988912   360  3588  3798  7898864925
# 5                КО7   3209325  2901198842  1622  1783  1401  2311158542
# 6                КО8  12263861           0     0     0     0           0
# 7                КО9   5208690  2138188211  1363  3960  2446  4380908694
# 8               КО11  12263861  2364020810   972  1098   362  2829917800
# 9               КО12  12263861           0     0     0     0           0
#
#          x7  x8  x9 ...   x59  x60  x61        x62   x63   x64         x65  \
# 0  0.000000   0   0 ...     0    0    1   7.171315   277   304    9.386282
# ...

# %%
df2 = data.drop(df.iloc[:,1:68]=0)
# Out:
#   File "<ipython-input-10-4ba8aff46975>", line 1
#     df2 = data.drop(df.iloc[:,1:68]=0)
#                    ^
# SyntaxError: keyword can't be an expression

# %%
df3=df.iloc[:,1:68]==0
df3
# Out:
#                       x2    x3    x4    x5    x6    x7    x8    x9   x10  \
# Кредит.организация
# КО2                 True  True  True  True  True  True  True  True  True
# КО3                 True  True  True  True  True  True  True  True  True
# КО4                 True  True  True  True  True  True  True  True  True
# КО5                 True  True  True  True  True  True  True  True  True
# КО6                 True  True  True  True  True  True  True  True  True
# КО7                 True  True  True  True  True  True  True  True  True
# КО8                 True  True  True  True  True  True  True  True  True
# КО9                 True  True  True  True  True  True  True  True  True
# КО11                True  True  True  True  True  True  True  True  True
# КО12                True  True  True  True  True  True  True  True  True
# КО14                True  True  True  True  True  True  True  True  True
# КО15                True  True  True  True  True  True  True  True  True
# ...
