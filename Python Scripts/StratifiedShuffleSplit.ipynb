# %%
import pandas as pd
import numpy as np

wine = pd.read_excel(r'C:\Jypiter\ochischennye_dannye.xlsx').iloc[:,1:69]
wine.head()

target = wine['bad']
data = wine.drop('bad',axis = 1)
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: bad, dtype: int64

# %%
from sklearn.cross_validation import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(target, n_iter=10, test_size=0.1)

for train_index, test_index in sss:
    xtrain, xtest = data.iloc[train_index], data.iloc[test_index]
    ytrain, ytest = target[train_index], target[test_index]

ytrain.value_counts()
ytest.value_counts()
# Out:
# C:\Programs\Anaconda\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 1    91
# 0    46
# Name: bad, dtype: int64

# %%
xtrain.head()
# Out:
#             x1          x2   x3    x4   x5          x6        x7  x8  x9  \
# 185    5208690   118019111  130   139  117   116502615   0.00000   0   1
# 1337  12263861           0    0     0    0           0   0.00000   0   0
# 440    1549037           0    0     0    0           0   0.00000   0   0
# 522   12263861  6579971928  896  1382  339  4949915237  10.78741   0   0
# 677    1517318           0    0     0    2           0   0.00000   0   0
#
#             x10    ...     x58  x59  x60  x61        x62  x63  x64        x65  \
# 185   193250281    ...      22    6    0    1  13.065327  220  230  10.000000
# 1337          0    ...       0    0    0    0   0.000000    0    0   0.000000
# 440           0    ...       2    0    0    0   0.000000   20   20  10.000000
# 522    24139633    ...       9    0    0    5  49.462366  563  695   1.598579
# 677           0    ...       0    1    0    0   0.000000    1    1   0.000000
#
#              x66       x67
# 185    90.454545  0.454545
# ...

# %%
xtest.assign(Name='test')
xtest.insert(0, 'test', '1')

xtrain.assign(Name='test')
xtrain.insert(0, 'test', '0')

xtest.append(xtrain).sort_index()
# Out:
#      test        x1           x2    x3    x4    x5          x6        x7  x8  \
# 0       0   5208690    157537353   205   223   114   169231559  0.000000   0
# 1       0  12263861            0     0     0     0           0  0.000000   0
# 2       1  12263861   8123066430   994   487   360   529987788  0.222585   0
# 3       0  12263861            0     0     0     0           0  0.000000   0
# 4       0   1931158    782988912   360  3588  3798  7898864925  1.545759   0
# 5       0   3209325   2901198842  1622  1783  1401  2311158542  0.161198   1
# 6       0  12263861            0     0     0     0           0  0.000000   0
# 7       0   5208690   2138188211  1363  3960  2446  4380908694  0.698592   0
# 8       0  12263861   2364020810   972  1098   362  2829917800  0.000000   1
# 9       0  12263861            0     0     0     0           0  0.000000   0
# 10      0   3861883  10124990502  1301  1228   753   899716059  0.027574   1
# ...
